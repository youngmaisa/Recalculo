# %%
import pandas as pd

# Definir la ruta de los archivos
ruta_archivo = r"C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024"
archivo_original = r"NUEVA BASE - PROACTIVO y RECEPTIVO.xlsx"

# Leer el archivo Excel
df = pd.read_excel(f"{ruta_archivo}\\{archivo_original}")

# Definir los valores que corresponden a RECEPTIVO
tipos_receptivo = ["PDV", "PDVX", "HC POWER", "PDVX POWER"]

# Filtrar los datos para RECEPTIVO y PROACTIVO
df_receptivo = df[df['TIPO'].isin(tipos_receptivo)]
df_proactivo = df[~df['TIPO'].isin(tipos_receptivo)]

# Guardar los resultados en dos archivos Excel
ruta_receptivo = f"{ruta_archivo}\\RECEPTIVO_2024.xlsx"
ruta_proactivo = f"{ruta_archivo}\\PROACTIVO_2024.xlsx"

df_receptivo.to_excel(ruta_receptivo, index=False)
df_proactivo.to_excel(ruta_proactivo, index=False)

# Mensaje de confirmación
print(f"Archivos guardados en: \n{ruta_receptivo}\n{ruta_proactivo}")
# Out:
# Archivos guardados en:
# C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\RECEPTIVO_2024.xlsx
# C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\PROACTIVO_2024.xlsx

# %%
import os 
# Crear las carpetas para PROACTIVO y RECEPTIVO si no existen
carpeta_receptivo = f"{ruta_archivo}\\RECEPTIVO_2024"
carpeta_proactivo = f"{ruta_archivo}\\PROACTIVO_2024"

os.makedirs(carpeta_receptivo, exist_ok=True)
os.makedirs(carpeta_proactivo, exist_ok=True)

# Función para guardar los archivos por mes
def guardar_por_mes(df, carpeta_destino):
    # Obtener los meses únicos en la columna MES
    meses_unicos = df['MES'].unique()
    
    for mes in meses_unicos:
        # Filtrar los datos para cada mes
        df_mes = df[df['MES'] == mes]
        
        # Crear el nombre del archivo Excel basado en el mes
        nombre_archivo = f"{mes}.xlsx"
        ruta_archivo_mes = os.path.join(carpeta_destino, nombre_archivo)
        
        # Guardar el archivo Excel para ese mes
        df_mes.to_excel(ruta_archivo_mes, index=False)
        print(f"Archivo guardado: {ruta_archivo_mes}")

# Guardar los archivos por mes para RECEPTIVO y PROACTIVO
guardar_por_mes(df_receptivo, carpeta_receptivo)
guardar_por_mes(df_proactivo, carpeta_proactivo)
# Out:
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\RECEPTIVO_2024\202407.xlsx
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\RECEPTIVO_2024\202408.xlsx
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\RECEPTIVO_2024\202409.xlsx
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\RECEPTIVO_2024\202410.xlsx
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\PROACTIVO_2024\202407.xlsx
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\PROACTIVO_2024\202408.xlsx
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\PROACTIVO_2024\202409.xlsx
# Archivo guardado: C:\Users\mmedinam\OneDrive - Entel Peru S.A\Documentos - EntelDrive_ __ Canal Masivo\Archivos_Recalculo\BASES\2024\PROACTIVO_2024\202410.xlsx
